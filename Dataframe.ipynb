# %%
import pyspark 
from pyspark.sql import SparkSession

# %%
spark:SparkSession = SparkSession.builder \
      .appName("Dataframe test") \
      .getOrCreate()   
spark
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/08/02 19:21:23 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/08/02 19:21:25 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://master:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# **Create Dataframe**

# %%
#Create df from data 
data = [('Alice', 1, 2001), ('Bob', 2, 2002), ('Bob', 2, 1999)]
df1 = spark.createDataFrame(data, ['name', 'age', 'birth year'])
df1.show()
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +-----+---+----------+
# | name|age|birth year|
# +-----+---+----------+
# |Alice|  1|      2001|
# |  Bob|  2|      2002|
# |  Bob|  2|      1999|
# +-----+---+----------+

# %%
#Create df from rdd

#data
columns = ["language","users_count"]
data = [("Java", "20000"), ("Python", "100000"), ("Scala", "3000")]

rdd = spark.sparkContext.parallelize(data)
print("Data: ")
print(rdd.collect())

print("Schema: ")
dfFromRDD = rdd.toDF(columns)
dfFromRDD.printSchema()
dfFromRDD.show()
# Out:
# Data:
# [('Java', '20000'), ('Python', '100000'), ('Scala', '3000')]
# Schema:
# root
#  |-- language: string (nullable = true)
#  |-- users_count: string (nullable = true)
#
# +--------+-----------+
# |language|users_count|
# +--------+-----------+
# |    Java|      20000|
# |  Python|     100000|
# |   Scala|       3000|
# +--------+-----------+

# %%
#Create df with data and schema
from pyspark.sql.types import StructType,StructField, StringType, IntegerType, DoubleType, BooleanType

data2 = [("James","","Smith","36636","M",3000),
    ("Michael","Rose","","40288","M",4000),
    ("Robert","","Williams","42114","M",4000),
    ("Maria","Anne","Jones","39192","F",4000),
    ("Jen","Mary","Brown","","F",-1)
  ]

schema = StructType([ \
    StructField("firstname",StringType(),True), \
    StructField("middlename",StringType(),True), \
    StructField("lastname",StringType(),True), \
    StructField("id", StringType(), True), \
    StructField("gender", StringType(), True), \
    StructField("salary", IntegerType(), True) \
  ])

df = spark.createDataFrame(data=data2,schema=schema)
df.printSchema()
df.show(truncate=False)
# Out:
# root
#  |-- firstname: string (nullable = true)
#  |-- middlename: string (nullable = true)
#  |-- lastname: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: integer (nullable = true)
#
# +---------+----------+--------+-----+------+------+
# |firstname|middlename|lastname|id   |gender|salary|
# +---------+----------+--------+-----+------+------+
# |James    |          |Smith   |36636|M     |3000  |
# |Michael  |Rose      |        |40288|M     |4000  |
# |Robert   |          |Williams|42114|M     |4000  |
# |Maria    |Anne      |Jones   |39192|F     |4000  |
# |Jen      |Mary      |Brown   |     |F     |-1    |
# +---------+----------+--------+-----+------+------+

# %%
#Create df by reading csv file
df2 = spark.read.options(header = True, delimiter = ',') \
    .csv("file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode.csv")
df2.show(vertical = True)
# Out:
# -RECORD 0-----------------------------------
#  RecordNumber        | 1
#  Zipcode             | 704
#  ZipCodeType         | STANDARD
#  City                | PARC PARQUE
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 17.96
#  Long                | -66.22
#  Xaxis               | 0.38
#  Yaxis               | -0.87
#  Zaxis               | 0.3
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Parc Parque, PR
#  Location            | NA-US-PR-PARC PARQUE
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 1-----------------------------------
#  RecordNumber        | 2
#  Zipcode             | 704
#  ZipCodeType         | STANDARD
#  City                | PASEO COSTA DEL SUR
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 17.96
#  Long                | -66.22
#  Xaxis               | 0.38
#  Yaxis               | -0.87
#  Zaxis               | 0.3
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Paseo Costa Del S...
#  Location            | NA-US-PR-PASEO CO...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 2-----------------------------------
#  RecordNumber        | 10
#  Zipcode             | 709
#  ZipCodeType         | STANDARD
#  City                | BDA SAN LUIS
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 18.14
#  Long                | -66.26
#  Xaxis               | 0.38
#  Yaxis               | -0.86
#  Zaxis               | 0.31
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Bda San Luis, PR
#  Location            | NA-US-PR-BDA SAN ...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 3-----------------------------------
#  RecordNumber        | 61391
#  Zipcode             | 76166
#  ZipCodeType         | UNIQUE
#  City                | CINGULAR WIRELESS
#  State               | TX
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 32.72
#  Long                | -97.31
#  Xaxis               | -0.1
#  Yaxis               | -0.83
#  Zaxis               | 0.54
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Cingular Wireless...
#  Location            | NA-US-TX-CINGULAR...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 4-----------------------------------
#  RecordNumber        | 61392
#  Zipcode             | 76177
#  ZipCodeType         | STANDARD
#  City                | FORT WORTH
#  State               | TX
#  LocationType        | PRIMARY
#  Lat                 | 32.75
#  Long                | -97.33
#  Xaxis               | -0.1
#  Yaxis               | -0.83
#  Zaxis               | 0.54
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Fort Worth, TX
#  Location            | NA-US-TX-FORT WORTH
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 2126
#  EstimatedPopulation | 4053
#  TotalWages          | 122396986
#  Notes               | null
# -RECORD 5-----------------------------------
#  RecordNumber        | 61393
#  Zipcode             | 76177
#  ZipCodeType         | STANDARD
#  City                | FT WORTH
#  State               | TX
#  LocationType        | ACCEPTABLE
#  Lat                 | 32.75
#  Long                | -97.33
#  Xaxis               | -0.1
#  Yaxis               | -0.83
#  Zaxis               | 0.54
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Ft Worth, TX
#  Location            | NA-US-TX-FT WORTH
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 2126
#  EstimatedPopulation | 4053
#  TotalWages          | 122396986
#  Notes               | null
# -RECORD 6-----------------------------------
#  RecordNumber        | 4
#  Zipcode             | 704
#  ZipCodeType         | STANDARD
#  City                | URB EUGENE RICE
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 17.96
#  Long                | -66.22
#  Xaxis               | 0.38
#  Yaxis               | -0.87
#  Zaxis               | 0.3
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Urb Eugene Rice, PR
#  Location            | NA-US-PR-URB EUGE...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 7-----------------------------------
#  RecordNumber        | 39827
#  Zipcode             | 85209
#  ZipCodeType         | STANDARD
#  City                | MESA
#  State               | AZ
#  LocationType        | PRIMARY
#  Lat                 | 33.37
#  Long                | -111.64
#  Xaxis               | -0.3
#  Yaxis               | -0.77
#  Zaxis               | 0.55
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Mesa, AZ
#  Location            | NA-US-AZ-MESA
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 14962
#  EstimatedPopulation | 26883
#  TotalWages          | 563792730
#  Notes               | no NWS data,
# -RECORD 8-----------------------------------
#  RecordNumber        | 39828
#  Zipcode             | 85210
#  ZipCodeType         | STANDARD
#  City                | MESA
#  State               | AZ
#  LocationType        | PRIMARY
#  Lat                 | 33.38
#  Long                | -111.84
#  Xaxis               | -0.31
#  Yaxis               | -0.77
#  Zaxis               | 0.55
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Mesa, AZ
#  Location            | NA-US-AZ-MESA
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 14374
#  EstimatedPopulation | 25446
#  TotalWages          | 471000465
#  Notes               | null
# -RECORD 9-----------------------------------
#  RecordNumber        | 49345
#  Zipcode             | 32046
#  ZipCodeType         | STANDARD
#  City                | HILLIARD
#  State               | FL
#  LocationType        | PRIMARY
#  Lat                 | 30.69
#  Long                | -81.92
#  Xaxis               | 0.12
#  Yaxis               | -0.85
#  Zaxis               | 0.51
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Hilliard, FL
#  Location            | NA-US-FL-HILLIARD
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 3922
#  EstimatedPopulation | 7443
#  TotalWages          | 133112149
#  Notes               | null
# -RECORD 10----------------------------------
#  RecordNumber        | 49346
#  Zipcode             | 34445
#  ZipCodeType         | PO BOX
#  City                | HOLDER
#  State               | FL
#  LocationType        | PRIMARY
#  Lat                 | 28.96
#  Long                | -82.41
#  Xaxis               | 0.11
#  Yaxis               | -0.86
#  Zaxis               | 0.48
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Holder, FL
#  Location            | NA-US-FL-HOLDER
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 11----------------------------------
#  RecordNumber        | 49347
#  Zipcode             | 32564
#  ZipCodeType         | STANDARD
#  City                | HOLT
#  State               | FL
#  LocationType        | PRIMARY
#  Lat                 | 30.72
#  Long                | -86.67
#  Xaxis               | 0.04
#  Yaxis               | -0.85
#  Zaxis               | 0.51
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Holt, FL
#  Location            | NA-US-FL-HOLT
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 1207
#  EstimatedPopulation | 2190
#  TotalWages          | 36395913
#  Notes               | null
# -RECORD 12----------------------------------
#  RecordNumber        | 49348
#  Zipcode             | 34487
#  ZipCodeType         | PO BOX
#  City                | HOMOSASSA
#  State               | FL
#  LocationType        | PRIMARY
#  Lat                 | 28.78
#  Long                | -82.61
#  Xaxis               | 0.11
#  Yaxis               | -0.86
#  Zaxis               | 0.48
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Homosassa, FL
#  Location            | NA-US-FL-HOMOSASSA
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 13----------------------------------
#  RecordNumber        | 10
#  Zipcode             | 708
#  ZipCodeType         | STANDARD
#  City                | BDA SAN LUIS
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 18.14
#  Long                | -66.26
#  Xaxis               | 0.38
#  Yaxis               | -0.86
#  Zaxis               | 0.31
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Bda San Luis, PR
#  Location            | NA-US-PR-BDA SAN ...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 14----------------------------------
#  RecordNumber        | 3
#  Zipcode             | 704
#  ZipCodeType         | STANDARD
#  City                | SECT LANAUSSE
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 17.96
#  Long                | -66.22
#  Xaxis               | 0.38
#  Yaxis               | -0.87
#  Zaxis               | 0.3
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Sect Lanausse, PR
#  Location            | NA-US-PR-SECT LAN...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 15----------------------------------
#  RecordNumber        | 54354
#  Zipcode             | 36275
#  ZipCodeType         | PO BOX
#  City                | SPRING GARDEN
#  State               | AL
#  LocationType        | PRIMARY
#  Lat                 | 33.97
#  Long                | -85.55
#  Xaxis               | 0.06
#  Yaxis               | -0.82
#  Zaxis               | 0.55
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Spring Garden, AL
#  Location            | NA-US-AL-SPRING G...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 16----------------------------------
#  RecordNumber        | 54355
#  Zipcode             | 35146
#  ZipCodeType         | STANDARD
#  City                | SPRINGVILLE
#  State               | AL
#  LocationType        | PRIMARY
#  Lat                 | 33.77
#  Long                | -86.47
#  Xaxis               | 0.05
#  Yaxis               | -0.82
#  Zaxis               | 0.55
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Springville, AL
#  Location            | NA-US-AL-SPRINGVILLE
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 4046
#  EstimatedPopulation | 7845
#  TotalWages          | 172127599
#  Notes               | null
# -RECORD 17----------------------------------
#  RecordNumber        | 54356
#  Zipcode             | 35585
#  ZipCodeType         | STANDARD
#  City                | SPRUCE PINE
#  State               | AL
#  LocationType        | PRIMARY
#  Lat                 | 34.37
#  Long                | -87.69
#  Xaxis               | 0.03
#  Yaxis               | -0.82
#  Zaxis               | 0.56
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Spruce Pine, AL
#  Location            | NA-US-AL-SPRUCE PINE
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 610
#  EstimatedPopulation | 1209
#  TotalWages          | 18525517
#  Notes               | null
# -RECORD 18----------------------------------
#  RecordNumber        | 76511
#  Zipcode             | 27007
#  ZipCodeType         | STANDARD
#  City                | ASH HILL
#  State               | NC
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 36.4
#  Long                | -80.56
#  Xaxis               | 0.13
#  Yaxis               | -0.79
#  Zaxis               | 0.59
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Ash Hill, NC
#  Location            | NA-US-NC-ASH HILL
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 842
#  EstimatedPopulation | 1666
#  TotalWages          | 28876493
#  Notes               | null
# -RECORD 19----------------------------------
#  RecordNumber        | 76512
#  Zipcode             | 27203
#  ZipCodeType         | STANDARD
#  City                | ASHEBORO
#  State               | NC
#  LocationType        | PRIMARY
#  Lat                 | 35.71
#  Long                | -79.81
#  Xaxis               | 0.14
#  Yaxis               | -0.79
#  Zaxis               | 0.58
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Asheboro, NC
#  Location            | NA-US-NC-ASHEBORO
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 8355
#  EstimatedPopulation | 15228
#  TotalWages          | 215474318
#  Notes               | null
# only showing top 20 rows

# %%
#Create df by reading all file in folder (cac file phai co cung schema)
df2 = spark.read.options(header = True, delimiter = ',') \
    .csv("file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data")
print(df2.count())
df2.show(vertical = True)
# Out:
# 42
# -RECORD 0-----------------------------------
#  RecordNumber        | 1
#  Zipcode             | 704
#  ZipCodeType         | STANDARD
#  City                | PARC PARQUE
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 17.96
#  Long                | -66.22
#  Xaxis               | 0.38
#  Yaxis               | -0.87
#  Zaxis               | 0.3
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Parc Parque, PR
#  Location            | NA-US-PR-PARC PARQUE
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 1-----------------------------------
#  RecordNumber        | 2
#  Zipcode             | 704
#  ZipCodeType         | STANDARD
#  City                | PASEO COSTA DEL SUR
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 17.96
#  Long                | -66.22
#  Xaxis               | 0.38
#  Yaxis               | -0.87
#  Zaxis               | 0.3
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Paseo Costa Del S...
#  Location            | NA-US-PR-PASEO CO...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 2-----------------------------------
#  RecordNumber        | 10
#  Zipcode             | 709
#  ZipCodeType         | STANDARD
#  City                | BDA SAN LUIS
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 18.14
#  Long                | -66.26
#  Xaxis               | 0.38
#  Yaxis               | -0.86
#  Zaxis               | 0.31
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Bda San Luis, PR
#  Location            | NA-US-PR-BDA SAN ...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 3-----------------------------------
#  RecordNumber        | 61391
#  Zipcode             | 76166
#  ZipCodeType         | UNIQUE
#  City                | CINGULAR WIRELESS
#  State               | TX
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 32.72
#  Long                | -97.31
#  Xaxis               | -0.1
#  Yaxis               | -0.83
#  Zaxis               | 0.54
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Cingular Wireless...
#  Location            | NA-US-TX-CINGULAR...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 4-----------------------------------
#  RecordNumber        | 61392
#  Zipcode             | 76177
#  ZipCodeType         | STANDARD
#  City                | FORT WORTH
#  State               | TX
#  LocationType        | PRIMARY
#  Lat                 | 32.75
#  Long                | -97.33
#  Xaxis               | -0.1
#  Yaxis               | -0.83
#  Zaxis               | 0.54
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Fort Worth, TX
#  Location            | NA-US-TX-FORT WORTH
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 2126
#  EstimatedPopulation | 4053
#  TotalWages          | 122396986
#  Notes               | null
# -RECORD 5-----------------------------------
#  RecordNumber        | 61393
#  Zipcode             | 76177
#  ZipCodeType         | STANDARD
#  City                | FT WORTH
#  State               | TX
#  LocationType        | ACCEPTABLE
#  Lat                 | 32.75
#  Long                | -97.33
#  Xaxis               | -0.1
#  Yaxis               | -0.83
#  Zaxis               | 0.54
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Ft Worth, TX
#  Location            | NA-US-TX-FT WORTH
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 2126
#  EstimatedPopulation | 4053
#  TotalWages          | 122396986
#  Notes               | null
# -RECORD 6-----------------------------------
#  RecordNumber        | 4
#  Zipcode             | 704
#  ZipCodeType         | STANDARD
#  City                | URB EUGENE RICE
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 17.96
#  Long                | -66.22
#  Xaxis               | 0.38
#  Yaxis               | -0.87
#  Zaxis               | 0.3
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Urb Eugene Rice, PR
#  Location            | NA-US-PR-URB EUGE...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 7-----------------------------------
#  RecordNumber        | 39827
#  Zipcode             | 85209
#  ZipCodeType         | STANDARD
#  City                | MESA
#  State               | AZ
#  LocationType        | PRIMARY
#  Lat                 | 33.37
#  Long                | -111.64
#  Xaxis               | -0.3
#  Yaxis               | -0.77
#  Zaxis               | 0.55
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Mesa, AZ
#  Location            | NA-US-AZ-MESA
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 14962
#  EstimatedPopulation | 26883
#  TotalWages          | 563792730
#  Notes               | no NWS data,
# -RECORD 8-----------------------------------
#  RecordNumber        | 39828
#  Zipcode             | 85210
#  ZipCodeType         | STANDARD
#  City                | MESA
#  State               | AZ
#  LocationType        | PRIMARY
#  Lat                 | 33.38
#  Long                | -111.84
#  Xaxis               | -0.31
#  Yaxis               | -0.77
#  Zaxis               | 0.55
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Mesa, AZ
#  Location            | NA-US-AZ-MESA
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 14374
#  EstimatedPopulation | 25446
#  TotalWages          | 471000465
#  Notes               | null
# -RECORD 9-----------------------------------
#  RecordNumber        | 49345
#  Zipcode             | 32046
#  ZipCodeType         | STANDARD
#  City                | HILLIARD
#  State               | FL
#  LocationType        | PRIMARY
#  Lat                 | 30.69
#  Long                | -81.92
#  Xaxis               | 0.12
#  Yaxis               | -0.85
#  Zaxis               | 0.51
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Hilliard, FL
#  Location            | NA-US-FL-HILLIARD
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 3922
#  EstimatedPopulation | 7443
#  TotalWages          | 133112149
#  Notes               | null
# -RECORD 10----------------------------------
#  RecordNumber        | 49346
#  Zipcode             | 34445
#  ZipCodeType         | PO BOX
#  City                | HOLDER
#  State               | FL
#  LocationType        | PRIMARY
#  Lat                 | 28.96
#  Long                | -82.41
#  Xaxis               | 0.11
#  Yaxis               | -0.86
#  Zaxis               | 0.48
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Holder, FL
#  Location            | NA-US-FL-HOLDER
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 11----------------------------------
#  RecordNumber        | 49347
#  Zipcode             | 32564
#  ZipCodeType         | STANDARD
#  City                | HOLT
#  State               | FL
#  LocationType        | PRIMARY
#  Lat                 | 30.72
#  Long                | -86.67
#  Xaxis               | 0.04
#  Yaxis               | -0.85
#  Zaxis               | 0.51
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Holt, FL
#  Location            | NA-US-FL-HOLT
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 1207
#  EstimatedPopulation | 2190
#  TotalWages          | 36395913
#  Notes               | null
# -RECORD 12----------------------------------
#  RecordNumber        | 49348
#  Zipcode             | 34487
#  ZipCodeType         | PO BOX
#  City                | HOMOSASSA
#  State               | FL
#  LocationType        | PRIMARY
#  Lat                 | 28.78
#  Long                | -82.61
#  Xaxis               | 0.11
#  Yaxis               | -0.86
#  Zaxis               | 0.48
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Homosassa, FL
#  Location            | NA-US-FL-HOMOSASSA
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 13----------------------------------
#  RecordNumber        | 10
#  Zipcode             | 708
#  ZipCodeType         | STANDARD
#  City                | BDA SAN LUIS
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 18.14
#  Long                | -66.26
#  Xaxis               | 0.38
#  Yaxis               | -0.86
#  Zaxis               | 0.31
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Bda San Luis, PR
#  Location            | NA-US-PR-BDA SAN ...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 14----------------------------------
#  RecordNumber        | 3
#  Zipcode             | 704
#  ZipCodeType         | STANDARD
#  City                | SECT LANAUSSE
#  State               | PR
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 17.96
#  Long                | -66.22
#  Xaxis               | 0.38
#  Yaxis               | -0.87
#  Zaxis               | 0.3
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Sect Lanausse, PR
#  Location            | NA-US-PR-SECT LAN...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 15----------------------------------
#  RecordNumber        | 54354
#  Zipcode             | 36275
#  ZipCodeType         | PO BOX
#  City                | SPRING GARDEN
#  State               | AL
#  LocationType        | PRIMARY
#  Lat                 | 33.97
#  Long                | -85.55
#  Xaxis               | 0.06
#  Yaxis               | -0.82
#  Zaxis               | 0.55
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Spring Garden, AL
#  Location            | NA-US-AL-SPRING G...
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | null
#  EstimatedPopulation | null
#  TotalWages          | null
#  Notes               | null
# -RECORD 16----------------------------------
#  RecordNumber        | 54355
#  Zipcode             | 35146
#  ZipCodeType         | STANDARD
#  City                | SPRINGVILLE
#  State               | AL
#  LocationType        | PRIMARY
#  Lat                 | 33.77
#  Long                | -86.47
#  Xaxis               | 0.05
#  Yaxis               | -0.82
#  Zaxis               | 0.55
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Springville, AL
#  Location            | NA-US-AL-SPRINGVILLE
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 4046
#  EstimatedPopulation | 7845
#  TotalWages          | 172127599
#  Notes               | null
# -RECORD 17----------------------------------
#  RecordNumber        | 54356
#  Zipcode             | 35585
#  ZipCodeType         | STANDARD
#  City                | SPRUCE PINE
#  State               | AL
#  LocationType        | PRIMARY
#  Lat                 | 34.37
#  Long                | -87.69
#  Xaxis               | 0.03
#  Yaxis               | -0.82
#  Zaxis               | 0.56
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Spruce Pine, AL
#  Location            | NA-US-AL-SPRUCE PINE
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 610
#  EstimatedPopulation | 1209
#  TotalWages          | 18525517
#  Notes               | null
# -RECORD 18----------------------------------
#  RecordNumber        | 76511
#  Zipcode             | 27007
#  ZipCodeType         | STANDARD
#  City                | ASH HILL
#  State               | NC
#  LocationType        | NOT ACCEPTABLE
#  Lat                 | 36.4
#  Long                | -80.56
#  Xaxis               | 0.13
#  Yaxis               | -0.79
#  Zaxis               | 0.59
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Ash Hill, NC
#  Location            | NA-US-NC-ASH HILL
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 842
#  EstimatedPopulation | 1666
#  TotalWages          | 28876493
#  Notes               | null
# -RECORD 19----------------------------------
#  RecordNumber        | 76512
#  Zipcode             | 27203
#  ZipCodeType         | STANDARD
#  City                | ASHEBORO
#  State               | NC
#  LocationType        | PRIMARY
#  Lat                 | 35.71
#  Long                | -79.81
#  Xaxis               | 0.14
#  Yaxis               | -0.79
#  Zaxis               | 0.58
#  WorldRegion         | NA
#  Country             | US
#  LocationText        | Asheboro, NC
#  Location            | NA-US-NC-ASHEBORO
#  Decommisioned       | FALSE
#  TaxReturnsFiled     | 8355
#  EstimatedPopulation | 15228
#  TotalWages          | 215474318
#  Notes               | null
# only showing top 20 rows

# %%
#Voi 1 schema cu the
schema = StructType() \
      .add("RecordNumber",IntegerType(),True) \
      .add("Zipcode",IntegerType(),True) \
      .add("City",StringType(),True) \
      .add("State",StringType(),True) \
      .add("Lat",DoubleType(),True) \
      .add("Long",DoubleType(),True) \
      .add("WorldRegion",StringType(),True) \
      .add("Country",StringType(),True) \
      .add("LocationText",StringType(),True) \
      .add("Location",StringType(),True) \
      .add("EstimatedPopulation",IntegerType(),True) \
      .add("Notes",StringType(),True)
      
df_with_schema = spark.read.format("csv") \
      .option("header", True) \
      .schema(schema) \
      .load("file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data")

df_with_schema.show(vertical=True)
# Out:
# 22/08/02 19:42:52 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv
# -RECORD 0----------------------------------
#  RecordNumber        | 1
#  Zipcode             | 704
#  City                | STANDARD
#  State               | PARC PARQUE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 17.96
#  Country             | -66.22
#  LocationText        | 0.38
#  Location            | -0.87
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 1----------------------------------
#  RecordNumber        | 2
#  Zipcode             | 704
#  City                | STANDARD
#  State               | PASEO COSTA DEL SUR
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 17.96
#  Country             | -66.22
#  LocationText        | 0.38
#  Location            | -0.87
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 2----------------------------------
#  RecordNumber        | 10
#  Zipcode             | 709
#  City                | STANDARD
#  State               | BDA SAN LUIS
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 18.14
#  Country             | -66.26
#  LocationText        | 0.38
#  Location            | -0.86
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 3----------------------------------
#  RecordNumber        | 61391
#  Zipcode             | 76166
#  City                | UNIQUE
#  State               | CINGULAR WIRELESS
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 32.72
#  Country             | -97.31
#  LocationText        | -0.1
#  Location            | -0.83
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 4----------------------------------
#  RecordNumber        | 61392
#  Zipcode             | 76177
#  City                | STANDARD
#  State               | FORT WORTH
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 32.75
#  Country             | -97.33
#  LocationText        | -0.1
#  Location            | -0.83
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 5----------------------------------
#  RecordNumber        | 61393
#  Zipcode             | 76177
#  City                | STANDARD
#  State               | FT WORTH
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 32.75
#  Country             | -97.33
#  LocationText        | -0.1
#  Location            | -0.83
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 6----------------------------------
#  RecordNumber        | 4
#  Zipcode             | 704
#  City                | STANDARD
#  State               | URB EUGENE RICE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 17.96
#  Country             | -66.22
#  LocationText        | 0.38
#  Location            | -0.87
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 7----------------------------------
#  RecordNumber        | 39827
#  Zipcode             | 85209
#  City                | STANDARD
#  State               | MESA
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 33.37
#  Country             | -111.64
#  LocationText        | -0.3
#  Location            | -0.77
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 8----------------------------------
#  RecordNumber        | 39828
#  Zipcode             | 85210
#  City                | STANDARD
#  State               | MESA
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 33.38
#  Country             | -111.84
#  LocationText        | -0.31
#  Location            | -0.77
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 9----------------------------------
#  RecordNumber        | 49345
#  Zipcode             | 32046
#  City                | STANDARD
#  State               | HILLIARD
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 30.69
#  Country             | -81.92
#  LocationText        | 0.12
#  Location            | -0.85
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 10---------------------------------
#  RecordNumber        | 49346
#  Zipcode             | 34445
#  City                | PO BOX
#  State               | HOLDER
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 28.96
#  Country             | -82.41
#  LocationText        | 0.11
#  Location            | -0.86
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 11---------------------------------
#  RecordNumber        | 49347
#  Zipcode             | 32564
#  City                | STANDARD
#  State               | HOLT
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 30.72
#  Country             | -86.67
#  LocationText        | 0.04
#  Location            | -0.85
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 12---------------------------------
#  RecordNumber        | 49348
#  Zipcode             | 34487
#  City                | PO BOX
#  State               | HOMOSASSA
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 28.78
#  Country             | -82.61
#  LocationText        | 0.11
#  Location            | -0.86
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 13---------------------------------
#  RecordNumber        | 10
#  Zipcode             | 708
#  City                | STANDARD
#  State               | BDA SAN LUIS
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 18.14
#  Country             | -66.26
#  LocationText        | 0.38
#  Location            | -0.86
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 14---------------------------------
#  RecordNumber        | 3
#  Zipcode             | 704
#  City                | STANDARD
#  State               | SECT LANAUSSE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 17.96
#  Country             | -66.22
#  LocationText        | 0.38
#  Location            | -0.87
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 15---------------------------------
#  RecordNumber        | 54354
#  Zipcode             | 36275
#  City                | PO BOX
#  State               | SPRING GARDEN
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 33.97
#  Country             | -85.55
#  LocationText        | 0.06
#  Location            | -0.82
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 16---------------------------------
#  RecordNumber        | 54355
#  Zipcode             | 35146
#  City                | STANDARD
#  State               | SPRINGVILLE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 33.77
#  Country             | -86.47
#  LocationText        | 0.05
#  Location            | -0.82
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 17---------------------------------
#  RecordNumber        | 54356
#  Zipcode             | 35585
#  City                | STANDARD
#  State               | SPRUCE PINE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 34.37
#  Country             | -87.69
#  LocationText        | 0.03
#  Location            | -0.82
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 18---------------------------------
#  RecordNumber        | 76511
#  Zipcode             | 27007
#  City                | STANDARD
#  State               | ASH HILL
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 36.4
#  Country             | -80.56
#  LocationText        | 0.13
#  Location            | -0.79
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 19---------------------------------
#  RecordNumber        | 76512
#  Zipcode             | 27203
#  City                | STANDARD
#  State               | ASHEBORO
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 35.71
#  Country             | -79.81
#  LocationText        | 0.14
#  Location            | -0.79
#  EstimatedPopulation | null
#  Notes               | NA
# only showing top 20 rows

# %% [markdown]
# **Save Dataframe**

# %%
#overwrite – mode is used to overwrite the existing file.
#append – To add the data to the existing file.
#ignore – Ignores write operation when the file already exists.
#error – This is a default option when the file already exists, it returns an error.

df_with_schema.write.option("header",True).mode("append") \
 .csv("file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/save_zipcode")
# Out:
# 22/08/02 19:47:59 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode2.csv
# 22/08/02 19:47:59 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv

# %% [markdown]
# **Transformations**

# %%
#data 
print(f"Number of records {df_with_schema.count()}") #Ham count la action
df_with_schema.show(vertical=True)
# Out:
# Number of records 42
# 22/08/02 19:53:27 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv
# -RECORD 0----------------------------------
#  RecordNumber        | 1
#  Zipcode             | 704
#  City                | STANDARD
#  State               | PARC PARQUE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 17.96
#  Country             | -66.22
#  LocationText        | 0.38
#  Location            | -0.87
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 1----------------------------------
#  RecordNumber        | 2
#  Zipcode             | 704
#  City                | STANDARD
#  State               | PASEO COSTA DEL SUR
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 17.96
#  Country             | -66.22
#  LocationText        | 0.38
#  Location            | -0.87
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 2----------------------------------
#  RecordNumber        | 10
#  Zipcode             | 709
#  City                | STANDARD
#  State               | BDA SAN LUIS
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 18.14
#  Country             | -66.26
#  LocationText        | 0.38
#  Location            | -0.86
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 3----------------------------------
#  RecordNumber        | 61391
#  Zipcode             | 76166
#  City                | UNIQUE
#  State               | CINGULAR WIRELESS
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 32.72
#  Country             | -97.31
#  LocationText        | -0.1
#  Location            | -0.83
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 4----------------------------------
#  RecordNumber        | 61392
#  Zipcode             | 76177
#  City                | STANDARD
#  State               | FORT WORTH
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 32.75
#  Country             | -97.33
#  LocationText        | -0.1
#  Location            | -0.83
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 5----------------------------------
#  RecordNumber        | 61393
#  Zipcode             | 76177
#  City                | STANDARD
#  State               | FT WORTH
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 32.75
#  Country             | -97.33
#  LocationText        | -0.1
#  Location            | -0.83
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 6----------------------------------
#  RecordNumber        | 4
#  Zipcode             | 704
#  City                | STANDARD
#  State               | URB EUGENE RICE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 17.96
#  Country             | -66.22
#  LocationText        | 0.38
#  Location            | -0.87
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 7----------------------------------
#  RecordNumber        | 39827
#  Zipcode             | 85209
#  City                | STANDARD
#  State               | MESA
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 33.37
#  Country             | -111.64
#  LocationText        | -0.3
#  Location            | -0.77
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 8----------------------------------
#  RecordNumber        | 39828
#  Zipcode             | 85210
#  City                | STANDARD
#  State               | MESA
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 33.38
#  Country             | -111.84
#  LocationText        | -0.31
#  Location            | -0.77
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 9----------------------------------
#  RecordNumber        | 49345
#  Zipcode             | 32046
#  City                | STANDARD
#  State               | HILLIARD
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 30.69
#  Country             | -81.92
#  LocationText        | 0.12
#  Location            | -0.85
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 10---------------------------------
#  RecordNumber        | 49346
#  Zipcode             | 34445
#  City                | PO BOX
#  State               | HOLDER
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 28.96
#  Country             | -82.41
#  LocationText        | 0.11
#  Location            | -0.86
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 11---------------------------------
#  RecordNumber        | 49347
#  Zipcode             | 32564
#  City                | STANDARD
#  State               | HOLT
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 30.72
#  Country             | -86.67
#  LocationText        | 0.04
#  Location            | -0.85
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 12---------------------------------
#  RecordNumber        | 49348
#  Zipcode             | 34487
#  City                | PO BOX
#  State               | HOMOSASSA
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 28.78
#  Country             | -82.61
#  LocationText        | 0.11
#  Location            | -0.86
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 13---------------------------------
#  RecordNumber        | 10
#  Zipcode             | 708
#  City                | STANDARD
#  State               | BDA SAN LUIS
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 18.14
#  Country             | -66.26
#  LocationText        | 0.38
#  Location            | -0.86
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 14---------------------------------
#  RecordNumber        | 3
#  Zipcode             | 704
#  City                | STANDARD
#  State               | SECT LANAUSSE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 17.96
#  Country             | -66.22
#  LocationText        | 0.38
#  Location            | -0.87
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 15---------------------------------
#  RecordNumber        | 54354
#  Zipcode             | 36275
#  City                | PO BOX
#  State               | SPRING GARDEN
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 33.97
#  Country             | -85.55
#  LocationText        | 0.06
#  Location            | -0.82
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 16---------------------------------
#  RecordNumber        | 54355
#  Zipcode             | 35146
#  City                | STANDARD
#  State               | SPRINGVILLE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 33.77
#  Country             | -86.47
#  LocationText        | 0.05
#  Location            | -0.82
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 17---------------------------------
#  RecordNumber        | 54356
#  Zipcode             | 35585
#  City                | STANDARD
#  State               | SPRUCE PINE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 34.37
#  Country             | -87.69
#  LocationText        | 0.03
#  Location            | -0.82
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 18---------------------------------
#  RecordNumber        | 76511
#  Zipcode             | 27007
#  City                | STANDARD
#  State               | ASH HILL
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 36.4
#  Country             | -80.56
#  LocationText        | 0.13
#  Location            | -0.79
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 19---------------------------------
#  RecordNumber        | 76512
#  Zipcode             | 27203
#  City                | STANDARD
#  State               | ASHEBORO
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 35.71
#  Country             | -79.81
#  LocationText        | 0.14
#  Location            | -0.79
#  EstimatedPopulation | null
#  Notes               | NA
# only showing top 20 rows

# %%
#Select 
selectColDf = df_with_schema.select("Zipcode", "City")
selectColDf.show()
# Out:
# [Stage 56:>                                                         (0 + 0) / 1]
# 22/08/02 19:55:18 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: Zipcode, ZipCodeType
#  Schema: Zipcode, City
# Expected: City but found: ZipCodeType
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv
# +-------+--------+
# |Zipcode|    City|
# +-------+--------+
# |    704|STANDARD|
# |    704|STANDARD|
# |    709|STANDARD|
# |  76166|  UNIQUE|
# |  76177|STANDARD|
# |  76177|STANDARD|
# |    704|STANDARD|
# |  85209|STANDARD|
# |  85210|STANDARD|
# |  32046|STANDARD|
# |  34445|  PO BOX|
# |  32564|STANDARD|
# |  34487|  PO BOX|
# |    708|STANDARD|
# |    704|STANDARD|
# |  36275|  PO BOX|
# |  35146|STANDARD|
# |  35585|STANDARD|
# |  27007|STANDARD|
# |  27203|STANDARD|
# +-------+--------+
# only showing top 20 rows

# %%
#drop 
dropedDf = df_with_schema.drop("Lat", "Long", "WorldRegion", "LocationText", "Notes")
dropedDf.show()
# Out:
# 22/08/02 21:28:53 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: RecordNumber, Zipcode, ZipCodeType, City, Long, Yaxis, Zaxis
#  Schema: RecordNumber, Zipcode, City, State, Country, Location, EstimatedPopulation
# Expected: City but found: ZipCodeType
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv
# +------------+-------+--------+-------------------+-------+--------+-------------------+
# |RecordNumber|Zipcode|    City|              State|Country|Location|EstimatedPopulation|
# +------------+-------+--------+-------------------+-------+--------+-------------------+
# |           1|    704|STANDARD|        PARC PARQUE| -66.22|   -0.87|               null|
# |           2|    704|STANDARD|PASEO COSTA DEL SUR| -66.22|   -0.87|               null|
# |          10|    709|STANDARD|       BDA SAN LUIS| -66.26|   -0.86|               null|
# |       61391|  76166|  UNIQUE|  CINGULAR WIRELESS| -97.31|   -0.83|               null|
# |       61392|  76177|STANDARD|         FORT WORTH| -97.33|   -0.83|               null|
# |       61393|  76177|STANDARD|           FT WORTH| -97.33|   -0.83|               null|
# |           4|    704|STANDARD|    URB EUGENE RICE| -66.22|   -0.87|               null|
# |       39827|  85209|STANDARD|               MESA|-111.64|   -0.77|               null|
# |       39828|  85210|STANDARD|               MESA|-111.84|   -0.77|               null|
# |       49345|  32046|STANDARD|           HILLIARD| -81.92|   -0.85|               null|
# |       49346|  34445|  PO BOX|             HOLDER| -82.41|   -0.86|               null|
# |       49347|  32564|STANDARD|               HOLT| -86.67|   -0.85|               null|
# |       49348|  34487|  PO BOX|          HOMOSASSA| -82.61|   -0.86|               null|
# |          10|    708|STANDARD|       BDA SAN LUIS| -66.26|   -0.86|               null|
# |           3|    704|STANDARD|      SECT LANAUSSE| -66.22|   -0.87|               null|
# |       54354|  36275|  PO BOX|      SPRING GARDEN| -85.55|   -0.82|               null|
# |       54355|  35146|STANDARD|        SPRINGVILLE| -86.47|   -0.82|               null|
# |       54356|  35585|STANDARD|        SPRUCE PINE| -87.69|   -0.82|               null|
# |       76511|  27007|STANDARD|           ASH HILL| -80.56|   -0.79|               null|
# |       76512|  27203|STANDARD|           ASHEBORO| -79.81|   -0.79|               null|
# +------------+-------+--------+-------------------+-------+--------+-------------------+
# only showing top 20 rows

# %%
#Filter 3 cach deu dc
from pyspark.sql.functions import col
filteredDf = dropedDf.filter(col("Zipcode") > 30000) \
                     .filter("RecordNumber >= 50000") \
                     .filter(dropedDf.City == "STANDARD")
filteredDf.show()

#ham where y het
# Out:
# 22/08/02 20:08:12 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: RecordNumber, Zipcode, ZipCodeType, City, Long, Yaxis, Zaxis
#  Schema: RecordNumber, Zipcode, City, State, Country, Location, EstimatedPopulation
# Expected: City but found: ZipCodeType
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv
# 22/08/02 20:08:12 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: RecordNumber, Zipcode, ZipCodeType, City, Long, Yaxis, Zaxis
#  Schema: RecordNumber, Zipcode, City, State, Country, Location, EstimatedPopulation
# Expected: City but found: ZipCodeType
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode2.csv
# +------------+-------+--------+-----------+-------+--------+-------------------+
# |RecordNumber|Zipcode|    City|      State|Country|Location|EstimatedPopulation|
# +------------+-------+--------+-----------+-------+--------+-------------------+
# |       61392|  76177|STANDARD| FORT WORTH| -97.33|   -0.83|               null|
# |       61393|  76177|STANDARD|   FT WORTH| -97.33|   -0.83|               null|
# |       54355|  35146|STANDARD|SPRINGVILLE| -86.47|   -0.82|               null|
# |       54356|  35585|STANDARD|SPRUCE PINE| -87.69|   -0.82|               null|
# |       61392|  76177|STANDARD| FORT WORTH| -97.33|   -0.83|               null|
# |       61393|  76177|STANDARD|   FT WORTH| -97.33|   -0.83|               null|
# |       54355|  35146|STANDARD|SPRINGVILLE| -86.47|   -0.82|               null|
# |       54356|  35585|STANDARD|SPRUCE PINE| -87.69|   -0.82|               null|
# +------------+-------+--------+-----------+-------+--------+-------------------+

# %%
#distinct Loai bo cac dong bi trung lap - Noi chung luc dau la 2 file y het nhau dc load vao, h loai trung lap la con 1 nua 
distinctDf = df_with_schema.distinct()
print(f"Number of records {distinctDf.count()}") #Ham count la action
distinctDf.show()
# Out:
# 22/08/02 20:10:03 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv
# 22/08/02 20:10:03 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode2.csv
# Number of records 21
# 22/08/02 20:10:06 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode2.csv
# 22/08/02 20:10:06 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv
# +------------+-------+--------+-------------------+----+----+-----------+-------+------------+--------+-------------------+-----+
# |RecordNumber|Zipcode|    City|              State| Lat|Long|WorldRegion|Country|LocationText|Location|EstimatedPopulation|Notes|
# +------------+-------+--------+-------------------+----+----+-----------+-------+------------+--------+-------------------+-----+
# |       49348|  34487|  PO BOX|          HOMOSASSA|null|null|      28.78| -82.61|        0.11|   -0.86|               null|   NA|
# |          10|    708|STANDARD|       BDA SAN LUIS|null|null|      18.14| -66.26|        0.38|   -0.86|               null|   NA|
# |       49347|  32564|STANDARD|               HOLT|null|null|      30.72| -86.67|        0.04|   -0.85|               null|   NA|
# |       54356|  35585|STANDARD|        SPRUCE PINE|null|null|      34.37| -87.69|        0.03|   -0.82|               null|   NA|
# |       76511|  27007|STANDARD|           ASH HILL|null|null|       36.4| -80.56|        0.13|   -0.79|               null|   NA|
# |       39827|  85209|STANDARD|               MESA|null|null|      33.37|-111.64|        -0.3|   -0.77|               null|   NA|
# |       39828|  85210|STANDARD|               MESA|null|null|      33.38|-111.84|       -0.31|   -0.77|               null|   NA|
# |           4|    704|STANDARD|    URB EUGENE RICE|null|null|      17.96| -66.22|        0.38|   -0.87|               null|   NA|
# |           1|    704|STANDARD|        PARC PARQUE|null|null|      17.96| -66.22|        0.38|   -0.87|               null|   NA|
# |       54354|  36275|  PO BOX|      SPRING GARDEN|null|null|      33.97| -85.55|        0.06|   -0.82|               null|   NA|
# |       61392|  76177|STANDARD|         FORT WORTH|null|null|      32.75| -97.33|        -0.1|   -0.83|               null|   NA|
# |       61393|  76177|STANDARD|           FT WORTH|null|null|      32.75| -97.33|        -0.1|   -0.83|               null|   NA|
# |       49346|  34445|  PO BOX|             HOLDER|null|null|      28.96| -82.41|        0.11|   -0.86|               null|   NA|
# |       54355|  35146|STANDARD|        SPRINGVILLE|null|null|      33.77| -86.47|        0.05|   -0.82|               null|   NA|
# |          10|    709|STANDARD|       BDA SAN LUIS|null|null|      18.14| -66.26|        0.38|   -0.86|               null|   NA|
# |       76513|  27204|  PO BOX|           ASHEBORO|null|null|      35.71| -79.81|        0.14|   -0.79|               null|   NA|
# |           3|    704|STANDARD|      SECT LANAUSSE|null|null|      17.96| -66.22|        0.38|   -0.87|               null|   NA|
# |       49345|  32046|STANDARD|           HILLIARD|null|null|      30.69| -81.92|        0.12|   -0.85|               null|   NA|
# |           2|    704|STANDARD|PASEO COSTA DEL SUR|null|null|      17.96| -66.22|        0.38|   -0.87|               null|   NA|
# |       61391|  76166|  UNIQUE|  CINGULAR WIRELESS|null|null|      32.72| -97.31|        -0.1|   -0.83|               null|   NA|
# +------------+-------+--------+-------------------+----+----+-----------+-------+------------+--------+-------------------+-----+
# only showing top 20 rows

# %%
#Sort theo mot cot nao do
sortedDf = distinctDf.sort(distinctDf.Zipcode.desc())
sortedDf.show()
# Out:
# [Stage 102:>                                                        (0 + 2) / 2]
# 22/08/02 21:33:28 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv
# 22/08/02 21:33:28 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode2.csv
# [Stage 104:>                                                        (0 + 1) / 1]
# +------------+-------+--------+-----------------+----+----+-----------+-------+------------+--------+-------------------+-----+
# |RecordNumber|Zipcode|    City|            State| Lat|Long|WorldRegion|Country|LocationText|Location|EstimatedPopulation|Notes|
# +------------+-------+--------+-----------------+----+----+-----------+-------+------------+--------+-------------------+-----+
# |       39828|  85210|STANDARD|             MESA|null|null|      33.38|-111.84|       -0.31|   -0.77|               null|   NA|
# |       39827|  85209|STANDARD|             MESA|null|null|      33.37|-111.64|        -0.3|   -0.77|               null|   NA|
# |       61392|  76177|STANDARD|       FORT WORTH|null|null|      32.75| -97.33|        -0.1|   -0.83|               null|   NA|
# |       61393|  76177|STANDARD|         FT WORTH|null|null|      32.75| -97.33|        -0.1|   -0.83|               null|   NA|
# |       61391|  76166|  UNIQUE|CINGULAR WIRELESS|null|null|      32.72| -97.31|        -0.1|   -0.83|               null|   NA|
# |       54354|  36275|  PO BOX|    SPRING GARDEN|null|null|      33.97| -85.55|        0.06|   -0.82|               null|   NA|
# |       54356|  35585|STANDARD|      SPRUCE PINE|null|null|      34.37| -87.69|        0.03|   -0.82|               null|   NA|
# |       54355|  35146|STANDARD|      SPRINGVILLE|null|null|      33.77| -86.47|        0.05|   -0.82|               null|   NA|
# |       49348|  34487|  PO BOX|        HOMOSASSA|null|null|      28.78| -82.61|        0.11|   -0.86|               null|   NA|
# |       49346|  34445|  PO BOX|           HOLDER|null|null|      28.96| -82.41|        0.11|   -0.86|               null|   NA|
# |       49347|  32564|STANDARD|             HOLT|null|null|      30.72| -86.67|        0.04|   -0.85|               null|   NA|
# |       49345|  32046|STANDARD|         HILLIARD|null|null|      30.69| -81.92|        0.12|   -0.85|               null|   NA|
# |       76513|  27204|  PO BOX|         ASHEBORO|null|null|      35.71| -79.81|        0.14|   -0.79|               null|   NA|
# |       76512|  27203|STANDARD|         ASHEBORO|null|null|      35.71| -79.81|        0.14|   -0.79|               null|   NA|
# |       76511|  27007|STANDARD|         ASH HILL|null|null|       36.4| -80.56|        0.13|   -0.79|               null|   NA|
# |          10|    709|STANDARD|     BDA SAN LUIS|null|null|      18.14| -66.26|        0.38|   -0.86|               null|   NA|
# |          10|    708|STANDARD|     BDA SAN LUIS|null|null|      18.14| -66.26|        0.38|   -0.86|               null|   NA|
# |           4|    704|STANDARD|  URB EUGENE RICE|null|null|      17.96| -66.22|        0.38|   -0.87|               null|   NA|
# |           1|    704|STANDARD|      PARC PARQUE|null|null|      17.96| -66.22|        0.38|   -0.87|               null|   NA|
# |           3|    704|STANDARD|    SECT LANAUSSE|null|null|      17.96| -66.22|        0.38|   -0.87|               null|   NA|
# +------------+-------+--------+-----------------+----+----+-----------+-------+------------+--------+-------------------+-----+
# only showing top 20 rows

# %% [markdown]
# **Action**

# %%
#describe
describeDf = distinctDf.describe()
describeDf.show(vertical=True)
# Out:
# 22/08/02 20:13:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode.csv
# 22/08/02 20:13:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 12
# CSV file: file:///home/iloveu/BK_bat_diet/20212/BigData/spark_test/zipcode_data/zipcode2.csv
# -RECORD 0----------------------------------
#  summary             | count
#  RecordNumber        | 21
#  Zipcode             | 21
#  City                | 21
#  State               | 21
#  Lat                 | 0
#  Long                | 0
#  WorldRegion         | 21
#  Country             | 21
#  LocationText        | 21
#  Location            | 21
#  EstimatedPopulation | 0
#  Notes               | 21
# -RECORD 1----------------------------------
#  summary             | mean
#  RecordNumber        | 40659.42857142857
#  Zipcode             | 34530.19047619047
#  City                | null
#  State               | null
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 28.67476190476191
#  Country             | -83.15952380952382
#  LocationText        | 0.10952380952380954
#  Location            | -0.8323809523809522
#  EstimatedPopulation | null
#  Notes               | null
# -RECORD 2----------------------------------
#  summary             | stddev
#  RecordNumber        | 28220.90159362636
#  Zipcode             | 29480.87406204071
#  City                | null
#  State               | null
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 7.170747254678287
#  Country             | 14.205006679403738
#  LocationText        | 0.2160897080028614
#  Location            | 0.03389760491609428
#  EstimatedPopulation | null
#  Notes               | null
# -RECORD 3----------------------------------
#  summary             | min
#  RecordNumber        | 1
#  Zipcode             | 704
#  City                | PO BOX
#  State               | ASH HILL
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 17.96
#  Country             | -111.64
#  LocationText        | -0.1
#  Location            | -0.77
#  EstimatedPopulation | null
#  Notes               | NA
# -RECORD 4----------------------------------
#  summary             | max
#  RecordNumber        | 76513
#  Zipcode             | 85210
#  City                | UNIQUE
#  State               | URB EUGENE RICE
#  Lat                 | null
#  Long                | null
#  WorldRegion         | 36.4
#  Country             | -97.33
#  LocationText        | 0.38
#  Location            | -0.87
#  EstimatedPopulation | null
#  Notes               | NA

# %%
#Explore data
print("Zipcode information: ")
describeData = describeDf.collect()
for data in describeData:
    print(f"{data.__getitem__('summary')} : {data.__getitem__('Zipcode')}")
# Out:
# Zipcode information:
# count : 21
# mean : 34530.19047619047
# stddev : 29480.87406204071
# min : 704
# max : 85210
